# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('ames.csv', encoding='latin-1')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Visualizations
plt.figure(figsize=(12,4))

# %%
# Box plot of SalePrice
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['SalePrice'])
plt.title('Box Plot of SalePrice')
plt.xlabel('SalePrice')
plt.show()

# TotRmsAbvGrd Distribution
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.hist(df['TotRmsAbvGrd'], bins=10, color='green', edgecolor='black')
plt.title('Distribution of TotRmsAbvGrd')
plt.xlabel('TotRmsAbvGrd')
plt.ylabel('Frequency')

# OverallCond Distribution
plt.figure(figsize=(14, 6))
plt.subplot(1, 3, 3)
df['OverallCond'].value_counts().sort_index().plot(kind='bar', color='purple')
plt.title('Distribution of OverallCond')
plt.xlabel('OverallCond')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Interpretive Text
print("Summary Statistics:")
print(summary_stats)

print("\nInterpretive Text:")
print("SalePrice: Range: The whiskers lines extending from the box show the range of SalePrice values, excluding any outliers. Outliers, if present, are shown as individual points beyond the whiskers. Skewness: The position of the median within the box indicates the skewness of the distribution. If the median close to the lower quartile (Q1), it suggests a left-skewed distribution, where lower sale prices are more common. Conversely, if the median is closer to the upper quartile (Q3), it suggests a right-skewed distribution, where higher sale prices are more common. Spread: The length of the box (IQR) provides a measure of the spread, variability of SalePrice values. A longer box indicates a larger spread, a shorter box suggests a smaller spread. Central Tendency: The median represents the central tendency of the SalePrice distribution. It divides the data into two equal halves,50% of the prices falling below the median,50% above. Outliers: Any data points that lie beyond the whiskers are considered outliers. These can be values that deviate significantly, the majority of the data points, may represent extreme sale prices")
print("TotRmsAbvGrd: The distribution of TotRmsAbvGrd shows that most houses have around 6 to 7 rooms above ground. There is a smaller number of houses with fewer or more rooms.")
print("OverallCond: The distribution of OverallCond reveals that the majority of houses have a condition rating of 5. There are fewer houses with higher or lower condition ratings.")
# Out:
# Summary Statistics:
#            SalePrice  TotRmsAbvGrd  OverallCond
# count    1460.000000   1460.000000  1460.000000
# mean   180921.195890      6.517808     5.575342
# std     79442.502883      1.625393     1.112799
# min     34900.000000      2.000000     1.000000
# 25%    129975.000000      5.000000     5.000000
# 50%    163000.000000      6.000000     5.000000
# 75%    214000.000000      7.000000     6.000000
# max    755000.000000     14.000000     9.000000
#
# Interpretive Text:
# ...

# %%
RoofStyle = df['RoofStyle'].value_counts()
plt.figure(figsize=(8, 6))
sns.barplot(x=RoofStyle.index, y=RoofStyle.values)
plt.title('Distribution of RoofStyle')
plt.xlabel('RoofStyle')
plt.ylabel('Count')
plt.xticks(rotation=50)
plt.show()
